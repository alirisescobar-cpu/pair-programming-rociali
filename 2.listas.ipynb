# %%
num_ventas = 6
print(num_ventas)
# Out:
# 6

# %% [markdown]
# Se puede modificar el contenido, conjunto de elementos.

# %%
print('el numero de ventas hoy es', num_ventas)
# Out:
# el numero de ventas hoy es 6

# %%
ventas = [3.5, 37, 2.5, 23, 43]
lista = ["a", "b", "c", "d", "e", "f", "g"]

# %%
print(lista)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
lista_peq = ["a", "b", "c"]

# %%
lista[-2]
# Out:
# 'f'

# %%
lista.index("d")
# Out:
# 3

# %%
lista_peq = [lista[1],lista[2]]

# %%
lista[1:5]
# Out:
# ['b', 'c', 'd', 'e']

# %%
lista_num = [1,2,3,4,5,6,7,8,9]

# %%
lista_num[::2]
# Out:
# [1, 3, 5, 7, 9]

# %%
lista_num[1::2]
# Out:
# [2, 4, 6, 8]

# %%
lista_num[::4]
# Out:
# [1, 5, 9]

# %%
lista_listas = [[1, 2, 3, 4], [5, 6, 7, 8, 9]]
type(lista_listas)
# Out:
# list

# %%
len(lista_listas)
# Out:
# 2

# %%
len(lista_num)
# Out:
# 9

# %%
lista_listas[1]
# Out:
# [5, 6, 7, 8, 9]

# %%
lista_listas[1][2]
# Out:
# 7

# %%
print(lista_listas)
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8, 9]]

# %%
8 in lista_listas
# Out:
# False

# %%
8 in lista_listas[1]
# Out:
# True

# %%
lista_listas[1].index(8)
# Out:
# 3

# %%
pos = lista_listas[1].index(8)
lista_listas[1][pos]
# Out:
# 8

# %%
print(pos)
# Out:
# 3
